# %%
import numpy as np
import pandas as pd
from jupyter_datatables import init_datatables_mode
init_datatables_mode()

df = pd.DataFrame({
	'A': np.random.rand(5),
	'B': [1, 1, 3, 2, 1],
	'C': 'foo',
	'C_': 'This is a very long sentence that should automatically be trimmed',
	'D': [
		pd.Timestamp('20010101'), pd.Timestamp('20010102'),
		pd.Timestamp('20010103'), pd.Timestamp('20010103'),
		pd.Timestamp('20010104')
	],
	'E': pd.Series([1.0] * 5).astype('float32'),
	'F': [False, True, False, False, True],
	'G': pd.Series([1] * 5, dtype='int8')
})
df
# Out:
# <div id="978a494b550098ed966438b3111c6f9fb56115fd52fdb3e5de25d18e147b3891_wrapper" class="dataTables_wrapper no-footer"><div class="dt-buttons">   <button class="dt-button buttons-print disabled" tabindex="0" aria-controls="978a494b550098ed966438b3111c6f9fb56115fd52fdb3e5de25d18e147b3891" type="button" disabled="" style="cursor: not-allowed; color: rgb(153, 153, 153);"><span>Print</span></button> <button class="dt-button buttons-csv buttons-html5 disabled" tabindex="0" aria-controls="978a494b550098ed966438b3111c6f9fb56115fd52fdb3e5de25d18e147b3891" type="button" disabled="" style="cursor: not-allowed; color: rgb(153, 153, 153);"><span>CSV</span></button> <button class="dt-button buttons-pdf buttons-html5 disabled" tabindex="0" aria-controls="978a494b550098ed966438b3111c6f9fb56115fd52fdb3e5de25d18e147b3891" type="button" disabled="" style="cursor: not-allowed; color: rgb(153, 153, 153);"><span>PDF</span></button> </div><div class="dataTables_length" id="978a494b550098ed966438b3111c6f9fb56115fd52fdb3e5de25d18e147b3891_length"><label>Show <select name="978a494b550098ed966438b3111c6f9fb56115fd52fdb3e5de25d18e147b3891_length" aria-controls="978a494b550098ed966438b3111c6f9fb56115fd52fdb3e5de25d18e147b3891" class="disabled" disabled="" style="cursor: not-allowed; color: rgb(153, 153, 153);"><option value="10">10</option><option value="25">25</option><option value="50">50</option><option value="100">100</option></select> entries</label></div><div id="978a494b550098ed966438b3111c6f9fb56115fd52fdb3e5de25d18e147b3891_filter" class="dataTables_filter"><label>Search:<input type="search" class="disabled" placeholder="" aria-controls="978a494b550098ed966438b3111c6f9fb56115fd52fdb3e5de25d18e147b3891" disabled="" style="cursor: not-allowed; color: rgb(153, 153, 153);"></label></div><div class="dataTables_scroll"><div class="dataTables_scrollHead" style="overflow: hidden; position: relative; border: 0px; width: 100%;"><div class="dataTables_scrollHeadInner" style="box-sizing: content-box; width: 1678.67px; padding-right: 0px;"><table border="1" class="dataframe table cell-border nowrap dataTable no-footer" role="grid" style="margin-left: 0px; width: 1678.67px;"><thead>
#     <tr style="text-align: right;" role="row"><th class="dt-body-center dt-head-center sorting" tabindex="0" aria-controls="978a494b550098ed966438b3111c6f9fb56115fd52fdb3e5de25d18e147b3891" rowspan="1" colspan="1" style="width: 0px;" aria-label=": activate to sort column ascending"></th><th class="dt-body-center dt-head-center sorting" tabindex="0" aria-controls="978a494b550098ed966438b3111c6f9fb56115fd52fdb3e5de25d18e147b3891" rowspan="1" colspan="1" style="width: 145.333px;" aria-label="A: activate to sort column ascending">A</th><th class="dt-body-center dt-head-center sorting" tabindex="0" aria-controls="978a494b550098ed966438b3111c6f9fb56115fd52fdb3e5de25d18e147b3891" rowspan="1" colspan="1" style="width: 146px;" aria-label="B: activate to sort column ascending">B</th><th class="dt-body-center dt-head-center sorting" tabindex="0" aria-controls="978a494b550098ed966438b3111c6f9fb56115fd52fdb3e5de25d18e147b3891" rowspan="1" colspan="1" style="width: 146px;" aria-label="C: activate to sort column ascending">C</th><th class="dt-body-center dt-head-center sorting" tabindex="0" aria-controls="978a494b550098ed966438b3111c6f9fb56115fd52fdb3e5de25d18e147b3891" rowspan="1" colspan="1" style="width: 333.333px;" aria-label="C_: activate to sort column ascending">C_</th><th class="dt-body-center dt-head-center sorting" tabindex="0" aria-controls="978a494b550098ed966438b3111c6f9fb56115fd52fdb3e5de25d18e147b3891" rowspan="1" colspan="1" style="width: 146px;" aria-label="D: activate to sort column ascending">D</th><th class="dt-body-center dt-head-center sorting" tabindex="0" aria-controls="978a494b550098ed966438b3111c6f9fb56115fd52fdb3e5de25d18e147b3891" rowspan="1" colspan="1" style="width: 146px;" aria-label="E: activate to sort column ascending">E</th><th class="dt-body-center dt-head-center sorting" tabindex="0" aria-controls="978a494b550098ed966438b3111c6f9fb56115fd52fdb3e5de25d18e147b3891" rowspan="1" colspan="1" style="width: 146px;" aria-label="F: activate to sort column ascending">F</th><th class="dt-body-center dt-head-center sorting" tabindex="0" aria-controls="978a494b550098ed966438b3111c6f9fb56115fd52fdb3e5de25d18e147b3891" rowspan="1" colspan="1" style="width: 146px;" aria-label="G: activate to sort column ascending">G</th></tr>
#   <tr role="row" class="dtype-preview">
#       <th class=" dt-body-center dt-head-center"></th>
#       <td class="column-dtype-preview dt-head-center" aria-label="dtype preview for column 1"><div class="dtype-container"><select role="option" class="dtype"><option value="float64">float64</option></select></div></td>
#       <td class="column-dtype-preview dt-head-center" aria-label="dtype preview for column 2"><div class="dtype-container"><select role="option" class="dtype"><option value="int64">int64</option></select></div></td>
#       <td class="column-dtype-preview dt-head-center" aria-label="dtype preview for column 3"><div class="dtype-container"><select role="option" class="dtype"><option value="object">object</option></select></div></td>
#       <td class="column-dtype-preview dt-head-center" aria-label="dtype preview for column 4"><div class="dtype-container"><select role="option" class="dtype"><option value="object">object</option></select></div></td>
#       <td class="column-dtype-preview dt-head-center" aria-label="dtype preview for column 5"><div class="dtype-container"><select role="option" class="dtype"><option value="datetime64[ns]">datetime64[ns]</option></select></div></td>
#       <td class="column-dtype-preview dt-head-center" aria-label="dtype preview for column 6"><div class="dtype-container"><select role="option" class="dtype"><option value="float32">float32</option></select></div></td>
#       <td class="column-dtype-preview dt-head-center" aria-label="dtype preview for column 7"><div class="dtype-container"><select role="option" class="dtype"><option value="bool">bool</option></select></div></td>
#       <td class="column-dtype-preview dt-head-center" aria-label="dtype preview for column 8"><div class="dtype-container"><select role="option" class="dtype"><option value="int8">int8</option></select></div></td>
#     </tr><tr role="row" class="column-data-preview">
#       <th class=" dt-body-center dt-head-center"></th>
#       <td class="column-data-preview" role="figure" aria-label="data preview for column 1"><div class="dt-chart-container"><div is="dt-container" class="dt-container dt-chart-toolbar"></div><img src="data:image/png;base64,..." class="dt-chart-image"></div></td>
#       <td class="column-data-preview" role="figure" aria-label="data preview for column 2"><div class="dt-chart-container"><div is="dt-container" class="dt-container dt-chart-toolbar"></div><img src="data:image/png;base64,..." class="dt-chart-image"></div></td>
#       <td class="column-data-preview" role="figure" aria-label="data preview for column 3"><div class="dt-chart-container"><div is="dt-container" class="dt-container dt-chart-toolbar"></div><img src="data:image/png;base64,..." class="dt-chart-image"></div></td>
#       <td class="column-data-preview" role="figure" aria-label="data preview for column 4"><div class="dt-chart-container"><div is="dt-container" class="dt-container dt-chart-toolbar"></div><img src="data:image/png;base64,..." class="dt-chart-image"></div></td>
#       <td class="column-data-preview" role="figure" aria-label="data preview for column 5"><div class="dt-chart-container"><div is="dt-container" class="dt-container dt-chart-toolbar"></div><img src="data:image/png;base64,..." class="dt-chart-image"></div></td>
#       <td class="column-data-preview" role="figure" aria-label="data preview for column 6"><div class="dt-chart-container"><div is="dt-container" class="dt-container dt-chart-toolbar"></div><img src="data:image/png;base64,..." class="dt-chart-image"></div></td>
#       <td
#           A  B    C                                                 C_  \
# 0  0.309121  1  foo  This is a very long sentence that should autom...
# 1  0.528871  1  foo  This is a very long sentence that should autom...
# 2  0.287646  3  foo  This is a very long sentence that should autom...
# 3  0.354136  2  foo  This is a very long sentence that should autom...
# 4  0.953066  1  foo  This is a very long sentence that should autom...
#
#            D    E      F  G
# 0 2001-01-01  1.0  False  1
# 1 2001-01-02  1.0   True  1
# 2 2001-01-03  1.0  False  1
# 3 2001-01-03  1.0  False  1
# 4 2001-01-04  1.0   True  1
